# %% [markdown]
# <a href="https://colab.research.google.com/github/Afitr06/citra-digital/blob/main/citra_sederhana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Muhamad Fitroh Sodikin
#2006164
#Informatika E
#ilkom A

from google.colab import drive
drive.mount('drives')
# Out:
# Drive already mounted at drives; to attempt to forcibly remount, call drive.mount("drives", force_remount=True).

# %%
import cv2 
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/drives/MyDrive/Colab Notebooks/spiderman.jpg', cv2.IMREAD_UNCHANGED)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=728x455 at 0x7F4A1EC27410>

# %%
print(img.shape)
# Out:
# (455, 728, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
img=cv2.imread('/content/drives/MyDrive/Colab Notebooks/spiderman.jpg', cv2.IMREAD_GRAYSCALE)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=728x455 at 0x7F4A0FA18650>

# %%
print(img.shape)
# Out:
# (455, 728)

# %%
cv2.imwrite('/content/drives/MyDrive/Colab Notebooks/spidermangrayscale.jpg',img)
# Out:
# True
